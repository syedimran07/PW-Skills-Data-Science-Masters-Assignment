# %% [markdown]
# ### Q1. What is a database? Differentiate between SQL and NoSQL databases.
#
# Ans: A database is a structured collection of data that is organized in a way that allows for efficient storage, retrieval, and manipulation of data. It serves as a central repository for storing and managing information, making it easier to organize and access data for various purposes.
#
#
# 1. SQL Databases(Structured Query Language):
#
# SQL databases are RELATIONAL DATABASE MANAGEMENT SYSTEM that use a structured format, known as tables, to organize and store data. Each table consists of rows and columns, and relationships between tables are established using keys. SQL databases have a predefined schema that defines the structure of the data. The schema specifies the types of data that can be stored, relationships between tables, and constraints on the data. SQL databases are generally vertically scalable, meaning you can increase the capacity of a single server by increasing things like CPU, RAM, or SSD on that server.
#
# Examples: MySQL, PostgreSQL, SQLite, Oracle Database.
#
#
# 2. NoSQL Databases:
#
# NoSQL databases are Non-relational or distributed database system and can store and handle unstructured or semi-structured data. They use various data models, such as document-oriented, key-value pairs, wide-column stores, or graph databases. NoSQL databases are schema-less or have a dynamic schema, allowing for flexibility in the types of data that can be stored. Each record can have different fields without requiring a predefined schema. NoSQL databases are often horizontally scalable, meaning you can scale out by adding more servers to your NoSQL database.
#
# Examples: MongoDB, Cassandra, Redis, Hbase.

# %% [markdown]
# ### Q2. What is DDL? Explain why CREATE, DROP, ALTER, and TRUNCATE are used with an example.
#
# Ans: DDL stands for Data Definition Language, and it is a subset of SQL (Structured Query Language) that is used to define and manage the structure of a database. DDL commands are responsible for defining and managing database objects, such as tables and indexes. The main DDL commands include CREATE, DROP, ALTER, and TRUNCATE.
#
# 1. CREATE:
#
# It is used to create new database objects, such as tables, indexes, or views.
#
# Example:
#
# ![image.png](attachment:image.png)
#
# 2. DROP:
#
# It is used to delete existing database objects, such as tables, indexes, or views.
#
# ![image-3.png](attachment:image-3.png)
#
# 3. ALTER:
#
# It is used to modify the structure of existing database objects, such as adding, deleting, or modifying columns in a table.
#
# ![image-2.png](attachment:image-2.png)
#
# 4. TRUNCATE:
#
# It is used to remove all records from a table, but unlike DELETE, it does not log individual row deletions and is faster.
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Q3. What is DML? Explain INSERT, UPDATE, and DELETE with an example.
#
#
# Ans: DML stands for Data Manipulation Language, and it is a subset of SQL (Structured Query Language) used for managing data within a database. DML commands are responsible for inserting, updating, and deleting data in database tables. The main DML commands include INSERT, UPDATE, and DELETE.
#
# 1. INSERT:
#
# It is used to insert new records (rows) into a table.
#
# ![image.png](attachment:image.png)
#
# 2. UPDATE:
#
# It is used to modify existing records in a table.
#
# ![image-2.png](attachment:image-2.png)
#
# 3. DELETE:
#
# It is used to remove records from a table.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Q4. What is DQL? Explain SELECT with an example.
#
#
# Ans: DQL stands for Data Query Language, and it is a subset of SQL (Structured Query Language) that is used for querying and retrieving data from a database. The primary DQL command is SELECT, which is used to retrieve data from one or more tables in a database.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5. Explain Primary Key and Foreign Key.
#
#
# Ans:
#
#
# Primary Key:
#
# A primary key is a field or a set of fields in a database table that uniquely identifies each record in that table. It must contain unique values, and it cannot have NULL values. The primary key is used to establish a link between different tables in a relational database. Typically, the primary key is chosen based on one or more columns that have unique values, such as an employee ID or a product code.
#
#
# Foreign Key:
#
# A foreign key is a field in a database table that is used to establish a link between the data in two tables. It creates a relationship between the tables by referencing the primary key of another table. The foreign key in one table typically points to the primary key in another table. This relationship helps maintain referential integrity, ensuring that the data in the related tables remains consistent.

# %% [markdown]
# ### Q6. Write a python code to connect MySQL to python. Explain the cursor() and execute() method.
#
# Ans:
#
#
# To connect Python to MySQL, we can use the "mysql-connector" library.
#
#
# ![image.png](attachment:image.png)
#
#
# 1. cursor() method:
#
# The cursor() method is used to create a cursor object, which allows you to interact with the database by executing SQL queries.
# A cursor is a pointer that points to a specific row within a result set.
# The cursor object provides methods like execute(), fetchall(), fetchone(), etc., to perform various database operations.
#
# 2. execute() method:
#
# The execute() method is used to execute a SQL query or command.
# It takes a string parameter representing the SQL query to be executed.
# After calling execute(), you may need to use other cursor methods like fetchall() or fetchone() to retrieve the results, depending on the type of query (e.g., SELECT, INSERT, UPDATE).

# %% [markdown]
# ### Q7. Give the order of execution of SQL clauses in an SQL query.
#
#
# Ans:
#
# The order of execution of SQL clauses in an SQL query generally follows the sequence below:
#
# 1. SELECT: Specifies the columns to be retrieved from one or more tables.
# 2. FROM: Specifies the table or tables from which to retrieve the data.
# 3. WHERE: Filters the rows based on a specified condition.
# 4. GROUP BY: Groups rows that have the same values into summary rows, like sum or count.
# 5. HAVING: Filters the results of the GROUP BY clause based on a specified condition.
# 6. ORDER BY: Sorts the result set based on specified columns and sort orders.
# 7. LIMIT / OFFSET: Limits the number of rows returned and provides an offset for pagination.
